# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import warnings
import seaborn as sns
from sklearn.metrics import r2_score
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('FCGR_Extention.xlsx')

# %%
Data_X = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.88)]['SIF'].values
Data_X1 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X2 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_Y = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.88)]['FCGR'].values
Data_Y1 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y2 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.3)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X,Data_Y,color= 'r',label = 'SR = 0.88')
sns.regplot(Data_X1,Data_Y1,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X2,Data_Y2,color= 'g',label = 'SR = 0.3')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X10 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.1)]['SIF'].values
Data_X11 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X21 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.75)]['SIF'].values
Data_Y10 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.1)]['FCGR'].values
Data_Y11 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y21 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.75)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X10,Data_Y10,color= 'g',label = 'SR = 0.1')
sns.regplot(Data_X11,Data_Y11,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X21,Data_Y21,color= 'r',label = 'SR = 0.75')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X100 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_X111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X211 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.79)]['SIF'].values
Data_Y100 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.3)]['FCGR'].values
Data_Y111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y211 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XY') & (df['Stress Ratio'] == 0.79)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X100,Data_Y100,color= 'g',label = 'SR = 0.3')
sns.regplot(Data_X111,Data_Y111,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X211,Data_Y211,color= 'r',label = 'SR = 0.79')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X1000 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.77)]['SIF'].values
Data_X1111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X2111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.45)]['SIF'].values
Data_Y1000 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.77)]['FCGR'].values
Data_Y1111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y2111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.45)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X1000,Data_Y1000,color= 'r',label = 'SR = 0.77')
sns.regplot(Data_X1111,Data_Y1111,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X2111,Data_Y2111,color= 'g',label = 'SR = 0.45')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X10000 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.86)]['SIF'].values
Data_X11111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X21111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_Y10000 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.86)]['FCGR'].values
Data_Y11111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y21111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.3)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X10000,Data_Y10000,color= 'r',label = 'SR = 0.86')
sns.regplot(Data_X11111,Data_Y11111,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X21111,Data_Y21111,color= 'g',label = 'SR = 0.3')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X100000 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.89)]['SIF'].values
Data_X111111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X211111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_Y100000 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.89)]['FCGR'].values
Data_Y111111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y211111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'YZ') & (df['Stress Ratio'] == 0.3)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X100000,Data_Y100000,color= 'r',label = 'SR = 0.89')
sns.regplot(Data_X111111,Data_Y111111,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X211111,Data_Y211111,color= 'g',label = 'SR = 0.3')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X1000000 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.79)]['SIF'].values
Data_X1111111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X2111111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_Y1000000 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.79)]['FCGR'].values
Data_Y1111111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y2111111 = df[(df['Post Processing'] == 'As Built') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.3)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X1000000,Data_Y1000000,color= 'r',label = 'SR = 0.79')
sns.regplot(Data_X1111111,Data_Y1111111,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X2111111,Data_Y2111111,color= 'g',label = 'SR = 0.3')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X10000000 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.85)]['SIF'].values
Data_X11111111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X21111111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_Y10000000 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.85)]['FCGR'].values
Data_Y11111111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y21111111 = df[(df['Post Processing'] == 'Stress Relieved') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.3)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X10000000,Data_Y10000000,color= 'r',label = 'SR = 0.85')
sns.regplot(Data_X11111111,Data_Y11111111,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X21111111,Data_Y21111111,color= 'g',label = 'SR = 0.3')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
Data_X100000000 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.9)]['SIF'].values
Data_X111111111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X211111111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_Y100000000 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.9)]['FCGR'].values
Data_Y111111111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y211111111 = df[(df['Post Processing'] == 'Heat Treated') & (df['Built Orientation'] == 'XZ') & (df['Stress Ratio'] == 0.3)]['FCGR'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X100000000,Data_Y100000000,color= 'r',label = 'SR = 0.9')
sns.regplot(Data_X111111111,Data_Y111111111,color= 'b',label = 'SR = 0.6')
sns.regplot(Data_X211111111,Data_Y211111111,color= 'g',label = 'SR = 0.3')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
# Out:
# Text(0, 0.5, 'Crack growth rate')

# %%
df['Post Processing'] = df['Post Processing'].astype('category')
df['Post Processing'] = df['Post Processing'].cat.codes
df['Built Orientation'] = df['Built Orientation'].astype('category')
df['Built Orientation'] = df['Built Orientation'].cat.codes

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['SIF','FCGR']] =scaler.fit_transform(df[['SIF','FCGR']])

# %%
X = df[['Post Processing','Built Orientation','Stress Ratio','SIF']]
Y = df[['FCGR']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,stratify = X[['Post Processing','Built Orientation','Stress Ratio']], test_size = 0.30, random_state = 123)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout
from tensorflow.keras import optimizers
def build_nn():
  network = Sequential()
  network.add(Dense(16, activation = 'relu',input_shape = (X_train.shape[1],)))
  network.add(Dense(16,activation = 'relu'))
  network.add(Dense(8,activation = 'relu'))
  network.add(Dense(8,activation = 'relu'))
  network.add(Dense(1))
  learning_rate = 0.001
  network.compile(optimizer ='adam',loss = 'mse',metrics = ['mse'])
  return network

# %%
model = build_nn()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 16)                80
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 8)                 72
#
#  dense_4 (Dense)             (None, 1)                 9
#
# ...
# Total params: 569
# Trainable params: 569
# Non-trainable params: 0
# _________________________________________________________________

# %%
all_mae_histories = []
tf.random.set_seed(123)
history = model.fit(X_test,Y_test,epochs = 400)
mae_history = history.history['mse']
all_mae_histories.append(mae_history)
# Out:
# Epoch 1/400
# 9/9 [==============================] - 1s 2ms/step - loss: 1.2560 - mse: 1.2560
# Epoch 2/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1620 - mse: 1.1620
# Epoch 3/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1415 - mse: 1.1415
# Epoch 4/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1354 - mse: 1.1354
# Epoch 5/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1287 - mse: 1.1287
# Epoch 6/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1218 - mse: 1.1218
# Epoch 7/400
# 9/9 [==============================] - 0s 3ms/step - loss: 1.1163 - mse: 1.1163
# Epoch 8/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1093 - mse: 1.1093
# Epoch 9/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1039 - mse: 1.1039
# Epoch 10/400
# 9/9 [==============================] - 0s 2ms/step - loss: 1.0972 - mse: 1.0972
# Epoch 11/400
# ...

# %%
print('Test r2_score',r2_score(Y_test,model.predict(X_test)))
print('Train r2_score',r2_score(Y_train,model.predict(X_train)))
# Out:
# Test r2_score 0.9365492409776672
# Train r2_score 0.9056812155342234

# %%
y_pred_final_nn = model.predict(X)
y_pred_final_nn_list = list(y_pred_final_nn)
df['Pred'] = y_pred_final_nn_list

# %%
avg_mae_history = [np.mean([x[i] for x in all_mae_histories]) for i in range(400)]
plt.plot(range(1,len(avg_mae_history)+1),avg_mae_history)
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.show()

# %%
df['Pred'] = df['Pred'].astype('float')

# %%
df['Stress Ratio'].value_counts()
# Out:
# 0.60    312
# 0.30    246
# 0.79     71
# 0.88     40
# 0.85     39
# 0.86     38
# 0.45     37
# 0.89     37
# 0.77     36
# 0.75     35
# 0.10     34
# 0.90     32
# Name: Stress Ratio, dtype: int64

# %%
Data_X = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.88)]['SIF'].values
Data_X1 = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X2 = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_Y = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.88)]['FCGR'].values
Data_Y1 = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y2 = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.3)]['FCGR'].values
Data_Yp = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.88)]['Pred'].values
Data_Y1p = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.6)]['Pred'].values
Data_Y2p = df[(df['Post Processing'] == 0) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.3)]['Pred'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X,Data_Y,color= 'r',label = 'SR = 0.88, Actual')
sns.regplot(Data_X,Data_Yp,color= 'm',label = 'SR = 0.88, Predicted')
sns.regplot(Data_X1,Data_Y1,color= 'b',label = 'SR = 0.6, Actual')
sns.regplot(Data_X1,Data_Y1p,color= 'y',label = 'SR = 0.6, Predicted')
sns.regplot(Data_X2,Data_Y2,color= 'g',label = 'SR = 0.3, Actual')
sns.regplot(Data_X2,Data_Y2p,color= 'k',label = 'SR = 0.3,Predicted')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
plt.title('Actual vs Predicted Plot for As-Bulit and XY Orientation')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Plot for As-Bulit and XY Orientation')

# %%
Data_X = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.3)]['SIF'].values
Data_X1 = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.6)]['SIF'].values
Data_X2 = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.79)]['SIF'].values
Data_Y = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.3)]['FCGR'].values
Data_Y1 = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.6)]['FCGR'].values
Data_Y2 = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.79)]['FCGR'].values
Data_Yp = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.3)]['Pred'].values
Data_Y1p = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.6)]['Pred'].values
Data_Y2p = df[(df['Post Processing'] == 1) & (df['Built Orientation'] == 0) & (df['Stress Ratio'] == 0.79)]['Pred'].values
import matplotlib.pyplot as plt
sns.regplot(Data_X,Data_Y,color= 'r',label = 'SR = 0.3, Actual')
sns.regplot(Data_X,Data_Yp,color= 'm',label = 'SR = 0.3, Predicted')
sns.regplot(Data_X1,Data_Y1,color= 'b',label = 'SR = 0.6, Actual')
sns.regplot(Data_X1,Data_Y1p,color= 'y',label = 'SR = 0.6, Predicted')
sns.regplot(Data_X2,Data_Y2,color= 'g',label = 'SR = 0.79, Actual')
sns.regplot(Data_X2,Data_Y2p,color= 'k',label = 'SR = 0.79,Predicted')
plt.legend()
plt.xlabel('SIF')
plt.ylabel('Crack growth rate')
plt.title('Actual vs Predicted Plot for Duplex Annealed and XY Orientation')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Plot for Duplex Annealed and XY Orientation')

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score, r2_score, mean_squared_error, mean_absolute_error
xgb_model = xgb.XGBRegressor(max_depth = 4)
xgb_model.fit(X_train,Y_train)
print('Test r2_score',r2_score(Y_test,xgb_model.predict(X_test)))
print('Train r2 Score',r2_score(Y_train,xgb_model.predict(X_train)))
# Out:
# [09:54:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test r2_score 0.8341966159499515
# Train r2 Score 0.9372340148775149

# %%
#RandomForest
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(max_depth = 6)
rf_model.fit(X_train,Y_train)
print('Test r2_score',r2_score(Y_test,rf_model.predict(X_test)))
print('Train r2 Score',r2_score(Y_train,rf_model.predict(X_train)))
# Out:
# Test r2_score 0.6490458525256031
# Train r2 Score 0.720068440890847

# %%
#Decision Trees
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(max_depth = 6)
dt_model.fit(X_train,Y_train)
print('Test r2_score',r2_score(Y_test,dt_model.predict(X_test)))
print('Train r2 Score',r2_score(Y_train,dt_model.predict(X_train)))
# Out:
# Test r2_score 0.5464859734734713
# Train r2 Score 0.600555654849088

# %%
# !pip install optuna
# Out:
# ...
#      |████████████████████████████████| 308 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 209 kB 53.9 MB/s
# ...
#      |████████████████████████████████| 80 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 75 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 112 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 149 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 49 kB 5.6 MB/s
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11136 sha256=f6c8321d6511e64cf228df0d6bbf3e42ad311c94e2af23125e12fcf154abfde4
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# ...

# %%
import optuna
def xgb_objective(trial):
    param = {
        'silent': 1,
        'random_state': 0,
        'objective': 'reg:linear',
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-4, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-4, 1.0),
        'n_estimators': trial.suggest_int('n_estimators',10,100),
        'learning_rate': trial.suggest_loguniform('learning_rste', 1e-4, 0.1),
        'max_depth':trial.suggest_int('max_depth',3,6)
    }
    bst = xgb.XGBRegressor(**param)
    bst.fit(X_train,Y_train)
    return math.sqrt(mean_squared_error(Y_test,bst.predict(X_test)))

# %%
import math
SEED = 42
np.random.seed(SEED)
xgb_study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(seed=SEED),pruner=optuna.pruners.SuccessiveHalvingPruner())
xgb_study.optimize(xgb_objective, n_trials=100)
# Out:
# [I 2022-01-04 09:54:55,055] A new study created in memory with name: no-name-e819b381-d37e-4974-a4e4-1ae604a7c860
# [I 2022-01-04 09:54:55,083] Trial 0 finished with value: 1.1531565393625327 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.024810409748678097, 'reg_alpha': 0.00042079886696066364, 'n_estimators': 24, 'learning_rste': 0.00014936568554617635, 'max_depth': 6}. Best is trial 0 with value: 1.1531565393625327.
# [I 2022-01-04 09:54:55,103] Trial 1 finished with value: 1.1523987658722445 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.7579479953348001, 'reg_alpha': 0.21368329072358744, 'n_estimators': 29, 'learning_rste': 0.0003511356313970409, 'max_depth': 3}. Best is trial 1 with value: 1.1523987658722445.
# ...

# %%
from typing import Callable
from typing import Optional

import numpy as np

from optuna._experimental import experimental
from optuna.logging import get_logger
from optuna.study import Study
from optuna.study import StudyDirection
from optuna.trial import FrozenTrial
from optuna.trial import TrialState
from optuna.visualization._utils import _check_plot_args
from optuna.visualization.matplotlib._matplotlib_imports import _imports


if _imports.is_successful():
    from optuna.visualization.matplotlib._matplotlib_imports import Axes
    from optuna.visualization.matplotlib._matplotlib_imports import plt

_logger = get_logger(__name__)

# %%
def optimization_history(
    study: Study,
    *,
    target: Optional[Callable[[FrozenTrial], float]] = None,
    target_name: str = "Objective Value",
) -> "Axes":
    """Plot optimization history of all trials in a study with Matplotlib.
    .. seealso::
        Please refer to :func:`optuna.visualization.plot_optimization_history` for an example.
    Example:
        The following code snippet shows how to plot optimization history.
        .. plot::
            import optuna
            def objective(trial):
                x = trial.suggest_float("x", -100, 100)
                y = trial.suggest_categorical("y", [-1, 0, 1])
                return x ** 2 + y
            sampler = optuna.samplers.TPESampler(seed=10)
            study = optuna.create_study(sampler=sampler)
            study.optimize(objective, n_trials=10)
            optuna.visualization.matplotlib.plot_optimization_history(study)
    Args:
        study:
            A :class:`~optuna.study.Study` object whose trials are plotted for their target values.
        target:
            A function to specify the value to display. If it is :obj:`None` and ``study`` is being
            used for single-objective optimization, the objective values are plotted.
            .. note::
                Specify this argument if ``study`` is being used for multi-objective optimization.
        target_name:
            Target's name to display on the axis label and the legend.
    Returns:
        A :class:`matplotlib.axes.Axes` object.
    Raises:
        :exc:`ValueError`:
            If ``target`` is :obj:`None` and ``study`` is being used for multi-objective
            optimization.
    """

    _imports.check()
    _check_plot_args(study, target, target_name)
    get_optimization_history_plot(study, target, target_name)
    return 0
def get_optimization_history_plot(
    study: Study,
    target: Optional[Callable[[FrozenTrial], float]],
    target_name: str,
) -> "Axes":

    # Set up the graph style.
    fig = plt.figure()
    plt.title("Optimization History Plot")
    plt.xlabel("#Trials")
    plt.ylabel(target_name)
    
    # Prepare data for plotting.
    trials = [t for t in study.trials if t.state == TrialState.COMPLETE]

    if len(trials) == 0:
        _logger.warning("Study instance does not contain trials.")
        return 0

    # Draw a scatter plot and a line plot.
    if target is None:
        if study.direction == StudyDirection.MINIMIZE:
            best_values = np.minimum.accumulate([t.value for t in trials])
        else:
            best_values = np.maximum.accumulate([t.value for t in trials])
        plt.scatter(
            x=[t.number for t in trials],
            y=[t.value for t in trials],
            color='blue',
            alpha=1,
            label=target_name,
        )
        plt.plot(
            [t.number for t in trials],
            best_values,
            marker="o",
            color='red',
            alpha=0.5,
            label="Best Value",
        )

        plt.legend()
    else:
        plt.scatter(
            x=[t.number for t in trials],
            y=[target(t) for t in trials],
            color='red',
            alpha=1,
            label=target_name,
        )
    plt.savefig('pd_opt_his.png',dpi = 1200,bbox_inches='tight')
    plt.show()

# %%
optimization_history(xgb_study)
# Out:
# 0

# %%
#Best parameters in XGB Algorithm
xgb_study.best_params
# Out:
# {'booster': 'dart',
#  'learning_rste': 0.099097434857572,
#  'max_depth': 6,
#  'n_estimators': 99,
#  'reg_alpha': 0.0831399858761147,
#  'reg_lambda': 0.0005474832759289752}

# %%
bst_params = {'booster': 'dart',
 'learning_rste': 0.099097434857572,
 'max_depth': 6,
 'n_estimators': 99,
 'reg_alpha': 0.0831399858761147,
 'reg_lambda': 0.0005474832759289752}

# %%
final_model = xgb.XGBRegressor(**bst_params)
final_model.fit(X_train,Y_train)
# Out:
# [09:56:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(booster='dart', learning_rste=0.099097434857572, max_depth=6,
#              n_estimators=99, reg_alpha=0.0831399858761147,
#              reg_lambda=0.0005474832759289752)

# %%
print(r2_score(Y_test,final_model.predict(X_test)))
print(mean_absolute_error(Y_test,final_model.predict(X_test)))
print(math.sqrt(mean_squared_error(Y_test,final_model.predict(X_test))))
# Out:
# 0.8988219807988724
# 0.19859092829683186
# 0.3493887392479479

# %%
print(r2_score(Y_train,final_model.predict(X_train)))
# Out:
# 0.9912009913784068

# %%
# !pip install eli5 
import eli5
from eli5.sklearn import PermutationImportance
# Out:
# ...
#      |████████████████████████████████| 106 kB 23.1 MB/s
# ...

# %%
from sklearn.inspection import permutation_importance
from matplotlib import pyplot
results = permutation_importance(model, X_train, Y_train, scoring='neg_mean_squared_error')
importance = results.importances_mean
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 2.83760
# Feature: 1, Score: 1.06775
# Feature: 2, Score: 1.41737
# Feature: 3, Score: 5.00484
